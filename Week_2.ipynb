# %% [markdown]
# <a href="https://colab.research.google.com/github/My1nonly/PCVK_smt6_2023/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Acessing My google drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread ('/content/drive/MyDrive/images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/Mydrive/PCVK_MM/Images/mandrill2.tiff',img5)

#tampilkan plat dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img = cv.imread('/content/drive/MyDrive/images/couple.tiff')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111)
ax.imshow(img)

# %%
imgRG = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgRG[:,:,2] = 0
plt.imshow(imgRG)

# %%
imgGB = cv.cvtColor(img, cv.COLOR_BGR2RGB)
imgGB[:,:,0] = 0
plt.imshow(imgGB)

# %%
imgZ1 = cv.imread('/content/drive/MyDrive/images/couple.tiff')
imgZ = cv.cvtColor(imgZ1, cv.COLOR_BGR2RGB)
plt.imshow(imgZ[5:30])

# %%
imgZ = cv.imread('/content/drive/MyDrive/images/couple.tiff')
imgZ = cv.cvtColor(imgZ, cv.COLOR_BGR2RGB)
plt.imshow(imgZ[10:100, 10:100])

# %%
imgR = cv.imread('/content/drive/MyDrive/images/couple.tiff')
imgR = cv.cvtColor(imgR, cv.COLOR_BGR2RGB)
cv.rectangle(imgR, pt1=(100,20), pt2=(200,300), color=(0, 255, 0), thickness=10)
cv.rectangle(imgR, pt1=(40,200), pt2=(100,255), color=(255, 255, 255), thickness=20)
cv.rectangle(imgR, pt1=(27,8), pt2=(20,50), color=(0, 255, 255), thickness=15)
cv.rectangle(imgR, pt1=(150,40), pt2=(100,200), color=(255, 255, 0), thickness=16)
cv.rectangle(imgR, pt1=(120,70), pt2=(90,30), color=(255, 0, 0), thickness=14)

plt.imshow(imgR)

# %%
imgUD = cv.flip(cv.cvtColor(imgR, cv.COLOR_BGR2RGB), 0)
plt.imshow(imgUD)

# %%
imghfz = cv.imread('/content/drive/MyDrive/images/hafiz.jpg')
imghfz = cv.cvtColor(imghfz, cv.COLOR_BGR2RGB)
plt.imshow(imghfz)

# %%
cv.rectangle(imghfz, pt1=(1200, 100), pt2=(400, 300), color=(0, 0, 0), thickness=5)
cv.circle(imghfz, center=(1200, ), radius=90, color=(255, 0, 0), thickness=5)

plt.imshow(imghfz)

# %%
cv.rectangle(imghfz, pt1=(1200, 700), pt2=(300, 100), color=(0, 0, 255), thickness=5)
cv.circle(imghfz, center=(1000,400 ), radius=200, color=(255, 0, 0), thickness=5)

plt.imshow(imghfz)

# %%
imgh = cv.imread('/content/drive/MyDrive/images/hafiz.jpg')
imgh = cv.cvtColor(imgh, cv.COLOR_BGR2RGB)
plt.imshow(imgh)


cv.rectangle(imgh, pt1=(1200, 700), pt2=(600, 100), color=(0, 0, 255), thickness=5)
cv.circle(imgh, center=(1000,400 ), radius=200, color=(255, 0, 0), thickness=5)

plt.imshow(imgh)

# %%
img = cv.imread('/content/drive/MyDrive/images/couple.tiff')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img[:,:,0] = 0
img[:,:,1] = 0
cv.rectangle(img, pt1=(0, 150), pt2=(100, img.shape[0]), color=(0, 255, 0), thickness=10)

plt.imshow(img)

# %%
img = cv.imread('/content/drive/MyDrive/images/couple.tiff')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img[:,:,0] = 0
img[:,:,1] = 0
cv.rectangle(img, pt1=(0, 150), pt2=(100, img.shape[0]), color=(0, 255, 0), thickness=10)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img, text='Hafiz', org=(10, 100), fontFace=font, fontScale=3, color=(255, 255, 255), thickness=2, lineType=cv.LINE_AA)

plt.imshow(img)
